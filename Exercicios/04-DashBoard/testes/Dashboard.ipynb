# %% [markdown]
# ### Dashboard | supermarket_sales.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Importando arquivo com pandas e visualizando arquivo

# %%
import pandas as pd

df = pd.read_csv('/Users/crisyuriok/Library/CloudStorage/OneDrive-Personal/1-BigDataDataAnalyticsPyhton/Exercicios/04-DashBoard/supermarket_sales.csv',
                        sep = ';', 
                        decimal=',',
                        encoding='utf-8')
                        # , converters={'Unit price':float, 'Total':float, 'cogs':float}

print(df.head())
print(df.shape)
# Out:
#    Unnamed: 0   Invoice ID Branch       City Customer type  Gender  \
# 0           0  750-67-8428      A     Yangon        Member  Female
# 1           1  226-31-3081      C  Naypyitaw        Normal  Female
# 2           2  631-41-3108      A     Yangon        Normal    Male
# 3           3  123-19-1176      A     Yangon        Member    Male
# 4           4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# ...

# %% [markdown]
# #### Faturamento por dia | Barras empilhadas

# %%
display(df.dtypes)
# Out:
# Unnamed: 0                   int64
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

fig1 = pd.pivot_table(df, values='Total', index='Date', columns=['City'], aggfunc='sum')
print(fig1)

g1 = fig1.plot(kind='bar', figsize=(10,5), stacked=True)
# Out:
# City        Mandalay  Naypyitaw     Yangon
# Date
# 1/1/2019   1536.6960   837.1650  2371.3200
# 1/10/2019  1348.5990  1480.8570   731.4930
# 1/11/2019        NaN   453.2955  1661.6670
# 1/12/2019  2312.1420  1443.5820  1429.0395
# 1/13/2019   735.1050   603.6975  1112.4015
# ...              ...        ...        ...
# 3/5/2019   3540.0015  2272.1895   418.6875
# 3/6/2019   2020.4205    38.8500  1033.3260
# 3/7/2019    297.9060   771.6660   368.6865
# 3/8/2019     92.5575  1440.5580  1592.2725
# 3/9/2019   3006.4860  1687.3710  2780.1900
#
# [89 rows x 3 columns]

# %% [markdown]
# #### Faturamento po tipo de produto | Barras empilhadas horizontal

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/Users/crisyuriok/Library/CloudStorage/OneDrive-Personal/1-BigDataDataAnalyticsPyhton/Exercicios/04-DashBoard/supermarket_sales.csv',
                        sep = ';', 
                        decimal=',',
                        encoding='utf-8')

groupBy = df.groupby()
    
# plt.barh(df['Product line'], df['Total']['City'].sum())

# plt.show()
# Out:
# {'Fashion accessories', 'Sports and travel', 'Food and beverages', 'Home and lifestyle', 'Health and beauty', 'Electronic accessories'}

# %% [markdown]
# #### Faturamento por filial | Barras

# %% [markdown]
# #### Faturamento por tipo de pagamento | Pizza

# %% [markdown]
# #### Avaliação | Barras Empilhadas

# %% [markdown]
# #### Distribuição de vendas no dia | Histograma

# %% [markdown]
# #### Forma de pagamento
