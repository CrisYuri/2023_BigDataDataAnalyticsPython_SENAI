# %%
for i in range(20):
    print(f"Inicializando a iteração -> {i}")
    if i > 8:
        print(f"Finalizando a instrução {i}")
        break
        print("Ação nunca vista")
    if(i > 4):
        print(f"Continuando a iteração -> {i}")
        continue
        print("Ação nunca vista")
    print(f"Loop normal -> iteração {i}")
    print(f"i^2 é {i**2}")

print("Próxima instrução...")
# Out:
# Inicializando a iteração -> 0
# Loop normal -> iteração 0
# i^2 é 0
# Inicializando a iteração -> 1
# Loop normal -> iteração 1
# i^2 é 1
# Inicializando a iteração -> 2
# Loop normal -> iteração 2
# i^2 é 4
# Inicializando a iteração -> 3
# Loop normal -> iteração 3
# i^2 é 9
# Inicializando a iteração -> 4
# Loop normal -> iteração 4
# i^2 é 16
# Inicializando a iteração -> 5
# Continuando a iteração -> 5
# Inicializando a iteração -> 6
# Continuando a iteração -> 6
# Inicializando a iteração -> 7
# Continuando a iteração -> 7
# Inicializando a iteração -> 8
# Continuando a iteração -> 8
# Inicializando a iteração -> 9
# Finalizando a instrução 9
# Próxima instrução...

# %%
#média de 4 notas

nota01 = float(input("Digite a nota do PRIMEIRO bimestre: "))
nota02 = float(input("Digite a nota do SEGUNDO bimestre: "))
nota03 = float(input("Digite a nota do TERCEIRO bimestre: "))
nota04 = float(input("Digite a nota do QUARTO bimestre: "))

media = (nota01+nota02+nota03+nota04)/4

print("A nota do 1o Bimestre é: ", nota01 )
print("A nota do 2o Bimestre é: ", nota02)
print("A nota do 3o Bimestre é: ", nota03)
print("A nota do 4o Bimestre é: ", nota04)

print("A nota média é: ", media)

if media >= 7:
    print("Aprovado")
else:    
    print("Não Aprovado")

#biblioteda estatística
import statistics as st

print('**-** Cálculo da média com a biblioteca satatistics **-**')

#calculando média dps conjuntos

print(st.mean([1, 3, 5, 7, 9, 11, 13]))
print(st.mean([1, 3, 5, 7, 9, 11]))
print(st.mean([-11, 5.5, -3.4, 7.1, -9, 22]))
# Out:
# A nota do 1o Bimestre é:  5.0
# A nota do 2o Bimestre é:  6.0
# A nota do 3o Bimestre é:  7.0
# A nota do 4o Bimestre é:  5.0
# A nota média é:  5.75
# Não Aprovado
# **-** Cálculo da média com a biblioteca satatistics **-**
# 7
# 6
# 1.8666666666666667

# %%
#Biblioteca estatística

import numpy as np
import statistics as st

print(st.mode([1, 1, 1 ,1 , 2, 3, 3, 3, 3, 4]))
print(st.mode(["red", "blue", "blue", "red", "green", "red", "red"]))
print(st.multimode('aabbbbccdddddeeffffffgg'))

#Biblioteca para statistica de arrays

from scipy import stats

res1 = stats.mode(np.array([1, 0, 0, 0, 1, 0, 0, 0, 1]))
arr = np.array([[1, 2, 3, 4, 5],
                [1, 2, 2, 2, 2],
                [4, 5, 7, 9, 4],
                [6, 7, 8, 9, 2],
                [2, 3, 4, 8, 6]])

res2 = stats.mode(arr)
print(res1.mode)
print(res1.count)
print(res2)
# Out:
# 1
# red
# ['f']
# 0
# 6
# ModeResult(mode=array([1, 2, 2, 9, 2], dtype=int64), count=array([2, 2, 1, 2, 2], dtype=int64))

# %%
import statistics as st

print(st.median([1, 3, 5]))
print(st.median([1, 3, 5, 7]))

print(st.median_low([1, 3, 5]))
print(st.median_low([1, 3, 5, 7]))


print(st.median_high([1, 3, 5]))
print(st.median_high([1, 3, 5, 7]))
# Out:
# 3
# 4.0
# 3
# 3
# 3
# 5

# %%
# Biblioteca estaística

import statistics as st

print(st.mean([3, 7, 6, 5, 4]))
print(st.variance([3, 7, 6, 5, 4]))
print(st.pvariance([3, 7, 6, 5, 4]))

# variance é a variância para uma amostra de uma população maior, (n-1)
# pvariance é a variância para uma população inteira, (n)

print(st.stdev([3, 7, 6, 5, 4]))
print(st.pstdev([3, 7, 6, 5, 4]))
# Out:
# 5
# 2.5
# 2
# 1.5811388300841898
# 1.4142135623730951

# %%
# Grafico de colunas

import numpy as np
import matplotlib.pyplot as plt

# Vetores de dados
faixaEtaria = np.array(['18-25', '26-35', '36-45', '46-55', '55+'])
renda = np.array([1805.45, 2458.12, 3752.12, 4120.89, 3486.22])

# Criação do gráfico de barras
plt.bar(faixaEtaria, renda, color='red')

# Dados numéricos no eixo x
plt.xticks(faixaEtaria)

# Nome do eixo Y
plt.ylabel('Renda média')

# Nome do eixo X
plt.xlabel('Faixa etária (anos)')

#Títlo do gráfco
plt.title('Renda média x Faixa etária no Brasil')

# Apresentação da figura
plt.show()

# %%
import matplotlib.pyplot as plt

produtos = ['Soja em grão', 'Cana de Açúcar', 'Milho em grão', 'Café em grão', 'Mandioca']

quantidade_pct = (33.6, 16.8, 10.3, 6.2, 3.8)

plt.figure(figsize=(12, 6))
plt.barh(produtos, quantidade_pct, color='green')

# Inserindo nome nos eixos e gráfico
plt.ylabel('Produtos Agrícolas')
plt.xlabel('Participação do produto [%]')
plt.title('5 Produtos com maior participação da industria agrícola')

plt.show()

# %%
import matplotlib.pyplot as plt

notas_pedro = [8, 9, 7, 8]
notas_maria = [5, 10, 6, 9]
notas_jose = [7, 7, 5, 8]

barWidth = 0.25

r1 = np.arange(len(notas_pedro))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

plt.bar(r1, notas_pedro, color = '#6A5ACD', width=barWidth, label='Pedro')
plt.bar(r2, notas_maria, color = '#6495ED', width=barWidth, label='Maria')
plt.bar(r3, notas_jose, color = '#080BFF', width=barWidth, label='José')

plt.xlabel('Provas')
plt.xticks([r + barWidth for r in range(len(notas_pedro))],
           ['Prova 1', 'Prova 2', 'Prova 3', 'Prova 4'])
plt.ylabel('Notas')
plt.title('Representação das notas de 3 alunos em 4 provas semestrais')

plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

gold = np.array((104, 50, 280))
stone = np.array((223, 140, 60))
wood = np.array((95, 228, 65))

resources = ['Ouro', 'Pedra', 'Madeira']

villages = ['Village A', 'Village B', 'Village C']

plt.figure(figsize=(10, 5))

plt.bar(villages, gold, color='gold')
plt.bar(villages, stone, color='grey', bottom = gold)
plt.bar(villages, wood, color='saddlebrown', bottom = gold + stone)

plt.xlabel('Vilas')
plt.ylabel('Quantidade de Recursos')
plt.title('Grafico de recursos de 3 vilas')

plt.legend(('Ouro', 'Pedra', 'Madeira'))

plt.show()

# %%
from numpy import mean
from numpy import std
from numpy import correlate
from numpy.random import randn
from numpy.random import seed
from matplotlib import pyplot

# semente para gerar números aleatórios
seed(1)

# preparação:
data1 = 20 * randn(1000) + 100
data2 = data1 + (10 * randn(1000) + 50)

#media e desvio padrão de data1
print('média de data1:' '', str(round(mean(data1),2)))
print('desvio padrão de data1:' '', str(round(std(data1),2)))

#media e desvio padrão de data2
print('média de data2:' '', str(round(mean(data2),2)))
print('desvio padrão de data2:' '', str(round(std(data2),2)))

# plot
pyplot.scatter(data1, data2, marker='*')
pyplot.title('Gráfico de Dispersão entre data1 e data2')
pyplot.show()
# Out:
# média de data1: 100.78
# desvio padrão de data1: 19.62
# média de data2: 151.05
# desvio padrão de data2: 22.36

# %%
import matplotlib.pyplot as plt

meses = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho']
valores = [105235, 107697, 110256, 109236, 108859, 109986]

plt.figure(figsize=(8,6))
plt.plot(meses, valores)
plt.ylim(104000, 112000)
plt.title('Faturamento no primeiro semestre de 2017')
plt.xlabel('Meses')
plt.ylabel('Faturamento em R$')
plt.show()

# %%
import matplotlib.pyplot as plt

# Conjunto de dados a serem plotados

labels = 'Carros', 'Motos', 'Ônibus', 'Caminhões'
sizes = [40, 30, 15, 20]

# Criando a área de plotagem
fig, ax1 = plt.subplots()

# Criando o gáfico
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)

# Apresentar a figura
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.colors import Normalize
from matplotlib.markers import MarkerStyle
from matplotlib.text import TextPath
from matplotlib.transforms import Affine2D

SUCCESS_SYMBOLS = [
    TextPath((0, 0), "☹"),
    TextPath((0, 0), "😒"),
    TextPath((0, 0), "☺"),
]

N = 25
np.random.seed(42)
skills = np.random.uniform(5, 80, size=N) * 0.1 + 5
takeoff_angles = np.random.normal(0, 90, N)
thrusts = np.random.uniform(size=N)
successful = np.random.randint(0, 3, size=N)
positions = np.random.normal(size=(N, 2)) * 5
data = zip(skills, takeoff_angles, thrusts, successful, positions)

cmap = plt.colormaps["plasma"]
fig, ax = plt.subplots()
fig.suptitle("Throwing success", size=14)
for skill, takeoff, thrust, mood, pos in data:
    t = Affine2D().scale(skill).rotate_deg(takeoff)
    m = MarkerStyle(SUCCESS_SYMBOLS[mood], transform=t)
    ax.plot(pos[0], pos[1], marker=m, color=cmap(thrust))
fig.colorbar(plt.cm.ScalarMappables(norm=Normalize(0, 1), cmap=cmap),
             ax=ax, label="Normalized Thrust [a.u.]")
ax.set_xlabel("X position [m]")
ax.set_ylabel("Y position [m]")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\ALUNO\Desktop\AulaDBPython\Aula5.ipynb Cell 13 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/ALUNO/Desktop/AulaDBPython/Aula5.ipynb#X31sZmlsZQ%3D%3D?line=28'>29</a>     m = MarkerStyle(SUCCESS_SYMBOLS[mood], transform=t)
#      <a href='vscode-notebook-cell:/c%3A/Users/ALUNO/Desktop/AulaDBPython/Aula5.ipynb#X31sZmlsZQ%3D%3D?line=29'>30</a>     ax.plot(pos[0], pos[1], marker=m, color=cmap(thrust))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ALUNO/Desktop/AulaDBPython/Aula5.ipynb#X31sZmlsZQ%3D%3D?line=30'>31</a> fig.colorbar(plt.cm.ScalarMappables(norm=Normalize(0, 1), cmap=cmap),
#      <a href='vscode-notebook-cell:/c%3A/Users/ALUNO/Desktop/AulaDBPython/Aula5.ipynb#X31sZmlsZQ%3D%3D?line=31'>32</a>              ax=ax, label="Normalized Thrust [a.u.]")
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6, 4), subplot_kw=dict(aspect='equal'))

recipe = ["Trigo",
          "Arroz",
          "Feijão",
          "Batata",
          "Aipim"]

data = [100, 250, 200, 120, 80]

def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))

    return "{:.1f}%\n({:d} kg)".format(pct, absolute)

wedges, texts, autotexts = ax.pie(data, autopct = lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, recipe,
          title="Produtos",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1),
          fontsize="9")

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Quantidade de itens do estoque em kg:")
             
plt.show()

# %%
import matplotlib.pyplot as plt

labels = ' Porção 1', 'Porção 2', 'Porção 3', 'Porção 4'
sizes = [10, 20, 30, 40]

explode = (0, 0.2, 0, 0)

fig1, ax1 = plt.subplots(figsize=(6,6))

c = ['#A08F9D', '#A37E9D', '#A63B95', '#BB0FA0']

ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90, colors=c)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

n = np.random.randn(1000000)

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].hist(n)
axes[0].set_title('Histograma')
axes[0].set_xlim((min(n), max(n)))

axes[1].boxplot(n)
axes[1].set_title('Boxplot')

plt.show()

# %%
import seaborn
