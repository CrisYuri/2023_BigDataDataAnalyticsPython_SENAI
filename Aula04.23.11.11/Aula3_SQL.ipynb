# %%
import plotly.graph_objs as go 
import pandas as pd
 
z_dataCSV = pd.read_csv('/Users/crisyuriok/Library/CloudStorage/OneDrive-Personal/1-BigDataDataAnalyticsPyhton/DataCSV.csv')

ﬁg = go.Figure(data=[go.Surface(z=z_dataCSV.values)])

ﬁg.update_layout ( title = 'Mt Bruno Elevation − .csv' , autosize = False,
                width = 500,
                height = 500,
                margin = dict (l = 90, r = 50, b = 65, t = 90))

ﬁg.show()

# %%
import plotly.graph_objs as go 
import pandas as pd
import numpy as np

pts = np.loadtxt(np.DataSource().open('/Users/crisyuriok/Library/CloudStorage/OneDrive-Personal/1-BigDataDataAnalyticsPyhton/DataTXT.txt'))
x, y, z = pts.T

fig = go.Figure(data=[go.Mesh3d(x=x, y=y, z=z, color='mediumturquoise', opacity=0.50)])

ﬁg.update_layout ( title = 'Mesh_dataset - .txt' , autosize = False,
                width = 500,
                height = 500,
                margin = dict (l = 90, r = 50, b = 65, t = 90))
ﬁg.show()
